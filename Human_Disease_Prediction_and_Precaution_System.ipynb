# %%
#import necessary library
from tkinter import *
from tkinter import messagebox
import numpy as np
import pandas as pd


#List of Diseases 
disease_list=['Fungal infection','Allergy','GERD','Chronic cholestasis','Drug Reaction',
'Peptic ulcer diseae','AIDS','Diabetes','Gastroenteritis','Bronchial Asthma','Hypertension',
' Migraine','Cervical spondylosis',
'Paralysis (brain hemorrhage)','Jaundice','Malaria','Chicken pox','Dengue','Typhoid','hepatitis A',
'Hepatitis B','Hepatitis C','Hepatitis D','Hepatitis E','Alcoholic hepatitis','Tuberculosis',
'Common Cold','Pneumonia','Dimorphic hemmorhoids(piles)',
'Heartattack','Varicoseveins','Hypothyroidism','Hyperthyroidism','Hypoglycemia','Osteoarthristis',
'Arthritis','(vertigo) Paroymsal  Positional Vertigo','Acne','Urinary tract infection','Psoriasis',
'Impetigo']


#List of the symptoms
symp_list=['back_pain','constipation','abdominal_pain','diarrhoea','mild_fever','yellow_urine',
'yellowing_of_eyes','acute_liver_failure','fluid_overload','swelling_of_stomach',
'swelled_lymph_nodes','malaise','blurred_and_distorted_vision','phlegm','throat_irritation',
'redness_of_eyes','sinus_pressure','runny_nose','congestion','chest_pain','weakness_in_limbs',
'fast_heart_rate','pain_during_bowel_movements','pain_in_anal_region','bloody_stool',
'irritation_in_anus','neck_pain','dizziness','cramps','bruising','obesity','swollen_legs',
'swollen_blood_vessels','puffy_face_and_eyes','enlarged_thyroid','brittle_nails',
'swollen_extremeties','excessive_hunger','extra_marital_contacts','drying_and_tingling_lips',
'slurred_speech','knee_pain','hip_joint_pain','muscle_weakness','stiff_neck','swelling_joints',
'movement_stiffness','spinning_movements','loss_of_balance','unsteadiness',
'weakness_of_one_body_side','loss_of_smell','bladder_discomfort','foul_smell_of urine',
'continuous_feel_of_urine','passage_of_gases','internal_itching','toxic_look_(typhos)',
'depression','irritability','muscle_pain','altered_sensorium','red_spots_over_body','belly_pain',
'abnormal_menstruation','dischromic _patches','watering_from_eyes','increased_appetite','polyuria',
'family_history','mucoid_sputum','rusty_sputum','lack_of_concentration','visual_disturbances','receiving_blood_transfusion',
'receiving_unsterile_injections','coma','stomach_bleeding','distention_of_abdomen',
'history_of_alcohol_consumption','fluid_overload','blood_in_sputum','prominent_veins_on_calf',
'palpitations','painful_walking','pus_filled_pimples','blackheads','scurring','skin_peeling',
'silver_like_dusting','small_dents_in_nails','inflammatory_nails','blister','red_sore_around_nose',
'yellow_crust_ooze']



#creating empty list to store symptoms given by user
input_list=[]
for i in range(0,len(symp_list)):
    input_list.append(0)

#import training dataset
df=pd.read_csv("TrainingDataset.csv")

#Replace disease with numbers in file using pandas replace function
df.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True)

#print(df.head())

X= df[symp_list]

#print(X)

y = df[["prognosis"]]

#converted into contigious flattened array
np.ravel(y)              
#print(y)

#import training dataset
tr=pd.read_csv("TestingDataset.csv")

#Replace disease with numbers in file using pandas replace function
tr.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True)

X_test= tr[symp_list]
y_test = tr[["prognosis"]]

#print(y_test)

np.ravel(y_test)


#Creating root 
root = Tk()     # window is created
root.configure(background='green')        #background colour of window is assigned
root.title(' Machine Learning Project ...')     #window title is assigned

# lc will contain result i.e. disease from below algorithm result which use in precautions function
lc=[]

pred1=StringVar()
def DecisionTree():
    
    #checking if atleast 2 symptoms are given by user or not
    if((Symptom1.get()=="Select Symptom1 Here") or (Symptom2.get()=="Select Symptom2 Here")):
        pred1.set(" ")
        pred=messagebox.askokcancel("Predictor","Kindly Fill atleast first two Symptoms")
        if pred:
            root.mainloop()
    else:
        from sklearn import tree

        model1 = tree.DecisionTreeClassifier() 
        model1 = model1.fit(X,y)
        #calculating accuracy
        from sklearn.metrics import accuracy_score
        y_pred=model1.predict(X_test)
        #print('DecisionTree Accuracy:' ,accuracy_score(y_test, y_pred))
        
        
        psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
        
        
        #creating for loop inside a for loop to match the symptoms given by user with the symptoms in symp_list
        for k in range(0,len(symp_list)):
            for z in psymptoms:
                if(z==symp_list[k]):
                    input_list[k]=1

        inputtest = [input_list]
        predict = model1.predict(inputtest)
        predicted=predict[0]

        disease_match='no'
        #Here, we again use a for loop inside a for loop to match the name of disease with the coreesponding disease number
        for a in range(0,len(disease_list)):
            if(predicted == a):
                lc.append(a)
                disease_match='yes'
                break


        if (disease_match=='yes'):
            pred1.set(" ")
            pred1.set(disease_list[a])
        else:
            pred1.set(" ")
            pred1.set("Not Found")


    
pred2=StringVar()
def randomforest():
    if((Symptom1.get()=="Select Symptom1 Here") or (Symptom2.get()=="Select Symptom2 Here")):
        pred1.set(" ")
        pred=messagebox.askokcancel("Predictor","Kindly Fill atleast first two Symptoms")
        if pred:
            root.mainloop()
    else:
  
        from sklearn.ensemble import RandomForestClassifier
        model2 = RandomForestClassifier()
        model2 = model2.fit(X,np.ravel(y))

        #calculating accuracy 
        from sklearn.metrics import accuracy_score
        y_pred=model2.predict(X_test)
        #print('Randomforest Accuracy:' ,accuracy_score(y_test, y_pred))
       
    
        psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]

        for k in range(0,len(symp_list)):
            for z in psymptoms:
                if(z==symp_list[k]):
                    input_list[k]=1

        inputtest = [input_list]
        predict = model2.predict(inputtest)
        predicted=predict[0]

        disease_match='no'
        for a in range(0,len(disease_list)):
            if(predicted == a):
                lc.append(a)
                disease_match='yes'
                break

        if (disease_match=='yes'):
            pred2.set(" ")
            pred2.set(disease_list[a])
        else:
            pred2.set(" ")
            pred2.set("Not Found")
            
pred3=StringVar()
def NaiveBayes():
    if((Symptom1.get()=="Select Symptom1 Here") or (Symptom2.get()=="Select Symptom2 Here")):
        pred1.set(" ")
        pred=messagebox.askokcancel("Predictor","Kindly Fill atleast first two Symptoms")
        if pred:
            root.mainloop()
    else:
        
        
        from sklearn.naive_bayes import GaussianNB
        model3 = GaussianNB()
        model3=model3.fit(X,np.ravel(y))
        #calculating accuracy
        from sklearn.metrics import accuracy_score
        y_pred=model3.predict(X_test)
        #print('NaiveBayes Accuracy:' ,accuracy_score(y_test, y_pred))
    

        psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
        for k in range(0,len(symp_list)):
            for z in psymptoms:
                if(z==symp_list[k]):
                    input_list[k]=1

        inputtest = [input_list]
        predict = model3.predict(inputtest)
        predicted=predict[0]

        disease_match='no'
        for a in range(0,len(disease_list)):
            if(predicted == a):
                lc.append(a)
                disease_match='yes'
                break

        if (disease_match=='yes'):
            pred3.set(" ")
            pred3.set(disease_list[a])
        else:
            pred3.set(" ")
            pred3.set("Not Found")

        
#Precautions variables
prec1=StringVar()
prec2=StringVar()
prec3=StringVar()
prec4=StringVar()
text1=StringVar()

def Precautions():

    if((Symptom1.get()=="Select Symptom1 Here") or (Symptom2.get()=="Select Symptom2 Here")):
        pass
    else:
        
        import pandas as pd
        df1=pd.read_csv("symptom_precaution.csv")
        df1.replace({'Disease':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True)
        
        df1.set_index("Disease" , inplace=True)

        #if any two or three algorithm predicted the same result then it will show precautions for them else for decision tree algo.
    
        if lc[0]==lc[1] or lc[0]==lc[2] :
            dis=lc[0]
        elif lc[1]==lc[2]:
            dis=lc[1]
        else:
            dis=lc[1]            #randomforest accuracy is high
        
        loc=df1.loc[dis]    
        prec1.set(" ")
        prec1.set(loc[0])
        prec2.set(" ")
        prec2.set(loc[1])
        prec3.set(" ")
        prec3.set(loc[2])
        prec4.set(" ")
        prec4.set(loc[3])
        
        pr['text'] = "Precautions"
        pr['text'] = "Precautions for "+disease_list[dis]
        

#reset function
prev_win=None
def Reset():
    global prev_win
    #all symptoms values again set to previous value
    Symptom1.set("Select Symptom1 Here")
    Symptom2.set("Select Symptom2 Here")
    Symptom3.set("Select Symptom3 Here")
    Symptom4.set("Select Symptom4 Here")
    Symptom5.set("Select Symptom5 Here")
    
    Name.delete(first=0,last=100)
    #reset prediction
    pred1.set(" ")
    pred2.set(" ")
    pred3.set(" ")
    #reset precautions
    prec1.set(" ")
    prec2.set(" ")
    prec3.set(" ")
    prec4.set(" ")
    pr['text']='Precautions'
    lc.clear()
    
    #clear input list
    input_list.clear()
    for i in range(0,len(symp_list)):
        input_list.append(0)
    
    
    try:
        prev_win.destroy()
        prev_win=None
    except AttributeError:
        pass
        

#gui 

Symptom1 = StringVar()
Symptom1.set("Select Symptom1 Here")

Symptom2 = StringVar()
Symptom2.set("Select Symptom2 Here")

Symptom3 = StringVar()
Symptom3.set("Select Symptom3 Here")

Symptom4 = StringVar()
Symptom4.set("Select Symptom4 Here")

Symptom5 = StringVar()
Symptom5.set("Select Symptom5 Here")

Name = StringVar()


#gui window heading
h1= Label(root, justify=CENTER, text="** Human Disease Prediction and Precaution System **", fg="blue", bg="Pink")
h1.config(font=("Times",30,"bold italic"))
h1.grid(row=2, column=0, columnspan=2, padx=100)

NameLb = Label(root, text="Name of the Patient", fg="Red", bg="Sky Blue")
NameLb.config(font=("Times",15,"bold italic"))
NameLb.grid(row=6, column=0, pady=15,padx=20, sticky=W)

S1Lb = Label(root, text="Symptom 1", fg="Blue", bg="Pink")
S1Lb.config(font=("Times",15,"bold italic"))
S1Lb.grid(row=7, column=0, pady=10,padx=20, sticky=W)

S2Lb = Label(root, text="Symptom 2", fg="White", bg="Purple")
S2Lb.config(font=("Times",15,"bold italic"))
S2Lb.grid(row=8, column=0, pady=10,padx=20, sticky=W)

S3Lb = Label(root, text="Symptom 3", fg="Green",bg="white")
S3Lb.config(font=("Times",15,"bold italic"))
S3Lb.grid(row=9, column=0, pady=10,padx=20, sticky=W)

S4Lb = Label(root, text="Symptom 4", fg="blue", bg="Yellow")
S4Lb.config(font=("Times",15,"bold italic"))
S4Lb.grid(row=10, column=0, pady=10,padx=20, sticky=W)

S5Lb = Label(root, text="Symptom 5", fg="purple", bg="light green")
S5Lb.config(font=("Times",15,"bold italic"))
S5Lb.grid(row=11, column=0, pady=10,padx=20, sticky=W)


dstLb = Label(root, text="DecisionTree", fg="white", bg="red")
dstLb.config(font=("Times",15,"bold italic"))
dstLb.grid(row=15, column=0, pady=10,padx=20,sticky=W)

rnfLb = Label(root, text="RandomForest", fg="Red", bg="orange")
rnfLb.config(font=("Times",15,"bold italic"))
rnfLb.grid(row=17, column=0, pady=10,padx=20, sticky=W)

nbLb = Label(root, text="NaiveBayes", fg="yellow", bg="brown")
nbLb.config(font=("Times",15,"bold italic"))
nbLb.grid(row=19, column=0, pady=10,padx=20, sticky=W)

OPTIONS = sorted(symp_list)

Name= Entry(root, textvariable=Name)
Name.grid(row=6, column=1)

S1 = OptionMenu(root, Symptom1,*OPTIONS)
S1.grid(row=7, column=1)
S1.config(bg = "gold")
S1["menu"].config(bg="gold")

S2 = OptionMenu(root, Symptom2,*OPTIONS)
S2.grid(row=8, column=1)
S2.config(bg = "gold")
S2["menu"].config(bg="gold")

S3 = OptionMenu(root, Symptom3,*OPTIONS)
S3.grid(row=9, column=1)
S3.config(bg = "gold")
S3["menu"].config(bg="gold")

S4 = OptionMenu(root, Symptom4,*OPTIONS)
S4.grid(row=10, column=1)
S4.config(bg = "gold")
S4["menu"].config(bg="gold")

S5 = OptionMenu(root, Symptom5,*OPTIONS)
S5.grid(row=11, column=1)
S5.config(bg = "gold")
S5["menu"].config(bg="gold")


dst = Button(root, text="Prediction 1", command=DecisionTree,bg="Red",fg="yellow")
dst.config(font=("Times",15,"bold italic"))
dst.grid(row=8, column=3,padx=10)

rnf = Button(root, text="Prediction 2", command=randomforest,bg="White",fg="green")
rnf.config(font=("Times",15,"bold italic"))
rnf.grid(row=9, column=3,padx=10)

nb = Button(root, text="Prediction 3", command=NaiveBayes,bg="Blue",fg="white")
nb.config(font=("Times",15,"bold italic"))
nb.grid(row=10, column=3,padx=10)

rs = Button(root,text="Reset ", command=Reset,bg="yellow",fg="purple",width=15)
rs.config(font=("Times",15,"bold italic"))
rs.grid(row=11,column=3,padx=10)

#labels to display disease predicted 
t1=Label(root,text="Decision Tree",height=1,bg="khaki1",width=40,fg="blue2",textvariable=pred1,relief="sunken")
t1.config(font=("Times",15,"bold italic"))
t1.grid(row=15, column=1, padx=10)

t2=Label(root,text="Random Forest",height=1,bg="maroon1" ,width=40,fg="dark green",textvariable=pred2,relief="sunken")
t2.config(font=("Times",15,"bold italic"))
t2.grid(row=17, column=1, padx=10)

t3=Label(root,text="Naive Bayes",height=1,bg="plum1",width=40,fg="red4",textvariable=pred3,relief="sunken")
t3.config(font=("Times",15,"bold italic"))
t3.grid(row=19, column=1, padx=10)

pr= Button(root,text="Precautions ", command=Precautions,bg="yellow2",fg="purple",width=25)
pr.config(font=("Times",15,"bold italic"))
pr.grid(row=21,column=1,padx=10)

#labels to display precautions
pr1=Label(root,height=1,bg="dark orchid1",width=40,fg="dark green",textvariable=prec1,relief="sunken")
pr1.config(font=("Times",15,"bold italic"))
pr1.grid(row=23, column=1, padx=10)

pr2=Label(root,height=1,bg="cyan" ,width=40,fg="red",textvariable=prec2,relief="sunken")
pr2.config(font=("Times",15,"bold italic"))
pr2.grid(row=25, column=1, padx=10)

pr3=Label(root,height=1,bg="coral" ,width=40,fg="navy",textvariable=prec3,relief="sunken")
pr3.config(font=("Times",15,"bold italic"))
pr3.grid(row=27, column=1, padx=10)

pr4=Label(root,height=1,bg="ivory2",width=40,fg="blue2",textvariable=prec4,relief="sunken")
pr4.config(font=("Times",15,"bold italic"))
pr4.grid(row=29, column=1, padx=10)


note="**notes**\n*first two symptoms are mandatary.\n*select all the symptoms for better accuracy.\n*click on Prediction buttons for predicting results & Precuations button for precuations."
noteLb = Label(root, text=note, fg="White", bg="brown")
noteLb.config(font=("Times",15,"bold italic"))
noteLb.grid(row=30, column=1, pady=20 )


root.mainloop()
